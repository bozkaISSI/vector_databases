# %%
from pymilvus import MilvusClient

host = "localhost"
port = "19530"

milvus_client = MilvusClient(
    host=host,
    port=port
)
# Out:
# 2025-04-26 20:02:34,143 [ERROR][_create_connection]: Failed to create new connection using: 3a82af3f09734d289995a9eeeb2b8a95 (milvus_client.py:916)
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 6
#       4 port = "19530"
# ----> 6 milvus_client = MilvusClient(
#       7     host=host,
#       8     port=port
#       9 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:64, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      52 """A client for the common Milvus use case.
#      53
#      54 This client attempts to hide away the complexity of using Pymilvus. In a lot ofcases what
#    (...)     62         to None.
#      63 """
# ---> 64 self._using = self._create_connection(
# ...
